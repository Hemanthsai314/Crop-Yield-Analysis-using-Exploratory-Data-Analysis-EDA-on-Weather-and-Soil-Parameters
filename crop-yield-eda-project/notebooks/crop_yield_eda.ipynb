# %% [markdown]
# # Crop Yield EDA
# This notebook performs a basic exploratory data analysis on crop yield data.

# %%
import pandas as pd
df = pd.read_csv('../data/sample_crop_yield.csv')
df.head()

# %%
df.describe()

# %%
df[['Yield','Rainfall','Temperature','Soil_pH','Nutrients']].corr()
